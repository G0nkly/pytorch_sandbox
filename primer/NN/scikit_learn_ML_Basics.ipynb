# %% [markdown]
# <a href="https://colab.research.google.com/github/G0nkly/pytorch_sandbox/blob/main/primer/NN/scikit_learn_ML_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Overview**
# ###### AI vs ML vs NN vs DL
# ---
#
# ![image.png](data:image/png;base64,...)
#
# ---
# Sources:
# * https://www.qlik.com/us/augmented-analytics/machine-learning-vs-ai
